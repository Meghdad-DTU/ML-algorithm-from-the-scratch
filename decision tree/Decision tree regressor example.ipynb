# %%
from DecisionTree import DecisionTreeRegressor
import numpy as np
from pprint import pprint
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
## convert text file into matrix
def file2matrix(filename , header = True, delimeter="\t", index_y = None):
    """
    Takes a .txt file and returns a list of column names,a matrix of features and
    a vectore of y in case of having a target variable.
    """    
    fr = open(filename)
    colName = []
    if header == True:
        colName = list(fr.readline().strip().split(delimeter))
    numberOfLines = len(fr.readlines())
    fr = open(filename)
    numberOfX = len(fr.readline().split(delimeter)) 
    if index_y is not None:
        numberOfX = len(fr.readline().split(delimeter))-1                   
    returnMatX = np.zeros((numberOfLines,numberOfX))
    classLabelVector = []
    fr = open(filename)
    firstRow = 0
    if header == True:
        firstRow = 1
    index = 0
    for line in fr.readlines()[firstRow:]:
        line = line.strip()                            
        listFromLine = line.split(delimeter)
        if index_y is not None:
            classLabelVector.append(float(listFromLine[index_y]))
            listFromLine.pop(index_y)
        fltListFromLine = list(map(lambda x: float(x) if x!="" else np.nan, listFromLine))                                 
        returnMatX[index,:] = fltListFromLine        
        index += 1
    return colName, returnMatX, classLabelVector

# %%
## Accuracy measures 
def compute_error(trues,predicted):
    corr=np.corrcoef(predicted,trues)[0,1]
    mae=np.mean(np.abs(predicted-trues))
    rae=np.sum(np.abs(predicted-trues))/np.sum(np.abs(trues-np.mean(trues)))
    rmse=np.sqrt(np.mean((predicted-trues)**2))
    r2=max(0,1-np.sum((trues-predicted)**2)/np.sum((trues-np.mean(trues))**2))
    return corr,mae,rae,rmse,r2

# %%
filename = 'abalone.txt'
colName, returnMatX, target = file2matrix(filename , header = False, delimeter="\t", index_y = -1)
X = returnMatX
y = np.array(target)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
model = DecisionTreeRegressor(min_size=3, tol_error=10, criterion="mae")
model.fit(X_train,y_train)
pprint(model.trees_)
# Out:
# {'col': 7,
#  'cut_off': 0.145,
#  'index_col': 7,
#  'left': {'col': 7,
#           'cut_off': 0.0675,
#           'index_col': 7,
#           'left': {'col': 6,
#                    'cut_off': 0.0275,
#                    'index_col': 6,
#                    'left': {'col': 4,
#                             'cut_off': 0.0525,
#                             'index_col': 4,
#                             'left': 4.066666666666666,
#                             'right': 5.5,
#                             'samples': 131},
#                    'right': {'col': 7,
#                              'cut_off': 0.048,
#                              'index_col': 7,
#                              'left': 6.321428571428571,
#                              'right': 6.969072164948454,
#                              'samples': 153},
#                    'samples': 284},
#           'right': {'col': 0,
#                     'cut_off': 0.0,
#                     'index_col': 0,
#                     'left': 9.25925925925926,
#                     'right': {'col': 3,
#                               'cut_off': 0.1,
#                               'index_col': 3,
#                               'left': {'col': 0,
#                                        'cut_off': 1.0,
#                                        'index_col': 0,
#                                        'left': 6.9787234042553195,
#                                        'right': 8.3,
#                                        'samples': 114},
#                               'right': 8.00327868852459,
#                               'samples': 419},
#                     'samples': 500},
#           'samples': 784},
#  'right': {'col': 7,
#            'cut_off': 0.39,
#            'index_col': 7,
#            'left': {'col': 7,
#                     'cut_off': 0.249,
#                     'index_col': 7,
#                     'left': {'col': 5,
#                              'cut_off': 0.3355,
#                              'index_col': 5,
#                              'left': {'col': 7,
#                                       'cut_off': 0.1945,
#                                       'index_col': 7,
#                                       'left': {'col': 5,
#                                                'cut_off': 0.211,
#                                                'index_col': 5,
#                                                'left': {'col': 4,
#                                                         'cut_off': 0.523,
#                                                         'index_col': 4,
#                                                         'left': 10.241379310344827,
#                                                         'right': {'col': 1,
#                                                                   'cut_off': 0.485,
#                                                                   'index_col': 1,
#                                                                   'left': 13.545454545454545,
#                                                                   'right': 10.166666666666666,
#                                                                   'samples': 17},
#                                                         'samples': 104},
#                                                'right': {'col': 6,
#                                                          'cut_off': 0.1495,
#                                                          'index_col': 6,
#                                                          'left': {'col': 0,
#                                                                   'cut_off': 0.0,
#                                                                   'index_col': 0,
#                                                                   'left': 9.846153846153847,
#                                                                   'right': 8.496350364963504,
#                                                                   'samples': 163},
#                                                          'right': 10.263157894736842,
#                                                          'samples': 201},
#                                                'samples': 305},
#                                       'right': {'col': 5,
#                                                 'cut_off': 0.2495,
#                                                 'index_col': 5,
#                                                 'left': {'col': 1,
#                                                          'cut_off': 0.5,
#                                                          'index_col': 1,
#                                                          'left': 13.482758620689655,
#                                                          'right': {'col': 4,
#                                                                    'cut_off': 0.6345,
#                                                                    'index_col': 4,
#                                                                    'left': 10.066666666666666,
#                                                                    'right': 14.714285714285714,
#                                                                    'samples': 22},
#                                                          'samples': 51},
#                                                 'right': {'col': 3,
#                                                           'cut_off': 0.145,
#                                                           'index_col': 3,
#                                                           'left': 10.210526315789474,
#                                                           'right': 11.72340425531915,
#                                                           'samples': 123},
#                                                 'samples': 174},
#                                       'samples': 479},
#                              'right': 9.035242290748899,
#                              'samples': 706},
#                     'right': {'col': 5,
#                               'cut_off': 0.422,
#                               'index_col': 5,
#                               'left': {'col': 7,
#                                        'cut_off': 0.29,
#                                        'index_col': 7,
#                                        'left': {'col': 2,
#                                                 'cut_off': 0.43,
#                                                 'index_col': 2,
#                                                 'left': {'col': 4,
#                                                          'cut_off': 0.926,
#                                                          'index_col': 4,
#                                                          'left': {'col': 5,
#                                                                   'cut_off': 0.308,
#                                                                   'index_col': 5,
#                                                                   'left': 14.022727272727273,
#                                                                   'right': 10.5,
#                                                                   'samples': 62},
#                                                          'right': 17.0,
#                                                          'samples': 67},
#                                                 'right': 11.019047619047619,
#                                                 'samples': 172},
#                                        'right': {'col': 3,
#                                                  'cut_off': 0.18,
#                                                  'index_col': 3,
#                                                  'left': {'col': 6,
#                                                           'cut_off': 0.158,
#                                                           'index_col': 6,
#                                                           'left': {'col': 6,
#                                                                    'cut_off': 0.129,
#                                                                    'index_col': 6,
#                                                                    'left': 10.0,
#                                                                    'right': 17.083333333333332,
#                                                                    'samples': 15},
#                                                           'right': 12.94059405940594,
#                                                           'samples': 116},
#                                                  'right': 15.16,
#                                                  'samples': 141},
#                                        'samples': 313},
#                               'right': {'col': 7,
#                                         'cut_off': 0.3145,
#                                         'index_col': 7,
#                                         'left': 9.969465648854962,
#                                         'right': {'col': 5,
#                                                   'cut_off': 0.5815,
#                                                   'index_col': 5,
#                                                   'left': 11.024875621890548,
#                                                   'right': {'col': 4,
#                                                             'cut_off': 1.488,
#                                                             'index_col': 4,
#                                                             'left': 10.063063063063064,
#                                                             'right': 11.071428571428571,
#                                                             'samples': 139},
#                                                   'samples': 340},
#                                         'samples': 602},
#                               'samples': 915},
#                     'samples': 1621},
#            'right': {'col': 5,
#                      'cut_off': 0.566,
#                      'index_col': 5,
#                      'left': {'col': 7,
#                               'cut_off': 0.41,
#                               'index_col': 7,
#                               'left': 13.827586206896552,
#                               'right': 15.653846153846153,
#                               'samples': 107},
#                      'right': {'col': 7,
#                                'cut_off': 0.58,
#                                'index_col': 7,
#                                'left': {'col': 7,
#                                         'cut_off': 0.45,
#                                         'index_col': 7,
#                                         'left': 11.09016393442623,
#                                         'right': {'col': 5,
#                                                   'cut_off': 0.7075,
#                                                   'index_col': 5,
#                                                   'left': 13.705882352941176,
#                                                   'right': 11.734177215189874,
#                                                   'samples': 130},
#                                         'samples': 252},
#                                'right': {'col': 5,
#                                          'cut_off': 1.0515,
#                                          'index_col': 5,
#                                          'left': {'col': 6,
#                                                   'cut_off': 0.3985,
#                                                   'index_col': 6,
#                                                   'left': {'col': 3,
#                                                            'cut_off': 0.215,
#                                                            'index_col': 3,
#                                                            'left': 17.0,
#                                                            'right': 23.5,
#                                                            'samples': 12},
#                                                   'right': 15.733333333333333,
#                                                   'samples': 27},
#                                          'right': 11.428571428571429,
#                                          'samples': 34},
#                                'samples': 286},
#                      'samples': 393},
#            'samples': 2014},
#  'samples': 2798}

# %%
pred = model.prediction(X_test)
corr, MAE, RAE, RMSE, R2 = compute_error(y_test,pred)
print("\nCorrCoef: %.3f\nMAE: %.3f\nRMSE: %.3f\nR2: %.3f" %(corr, MAE,RMSE, R2))
# Out:
# CorrCoef: 0.710
# MAE: 1.569
# RMSE: 2.217
# R2: 0.496

# %%
## post_pruning
tree = model.trees_
testData = np.hstack((X_test, y_test.reshape(-1,1)))
pprint(model.prune(tree, testData))
# Out:
# merging
# merging
# merging
# merging
# merging
# {'col': 7,
#  'cut_off': 0.145,
#  'index_col': 7,
#  'left': {'col': 7,
#           'cut_off': 0.0675,
#           'index_col': 7,
#           'left': {'col': 6,
#                    'cut_off': 0.0275,
#                    'index_col': 6,
#                    'left': {'col': 4,
#                             'cut_off': 0.0525,
#                             'index_col': 4,
#                             'left': 4.066666666666666,
#                             'right': 5.5,
#                             'samples': 131},
#                    'right': {'col': 7,
#                              'cut_off': 0.048,
#                              'index_col': 7,
#                              'left': 6.321428571428571,
#                              'right': 6.969072164948454,
#                              'samples': 153},
#                    'samples': 284},
#           'right': {'col': 0,
#                     'cut_off': 0.0,
#                     'index_col': 0,
#                     'left': 9.25925925925926,
#                     'right': {'col': 3,
#                               'cut_off': 0.1,
#                               'index_col': 3,
#                               'left': {'col': 0,
#                                        'cut_off': 1.0,
#                                        'index_col': 0,
#                                        'left': 6.9787234042553195,
#                                        'right': 8.3,
#                                        'samples': 114},
#                               'right': 8.00327868852459,
#                               'samples': 419},
#                     'samples': 500},
#           'samples': 784},
#  'right': {'col': 7,
#            'cut_off': 0.39,
#            'index_col': 7,
#            'left': {'col': 7,
#                     'cut_off': 0.249,
#                     'index_col': 7,
#                     'left': {'col': 5,
#                              'cut_off': 0.3355,
#                              'index_col': 5,
#                              'left': {'col': 7,
#                                       'cut_off': 0.1945,
#                                       'index_col': 7,
#                                       'left': {'col': 5,
#                                                'cut_off': 0.211,
#                                                'index_col': 5,
#                                                'left': {'col': 4,
#                                                         'cut_off': 0.523,
#                                                         'index_col': 4,
#                                                         'left': 10.241379310344827,
#                                                         'right': {'col': 1,
#                                                                   'cut_off': 0.485,
#                                                                   'index_col': 1,
#                                                                   'left': 13.545454545454545,
#                                                                   'right': 10.166666666666666,
#                                                                   'samples': 17},
#                                                         'samples': 104},
#                                                'right': {'col': 6,
#                                                          'cut_off': 0.1495,
#                                                          'index_col': 6,
#                                                          'left': 9.171252105558676,
#                                                          'right': 10.263157894736842,
#                                                          'samples': 201},
#                                                'samples': 305},
#                                       'right': {'col': 5,
#                                                 'cut_off': 0.2495,
#                                                 'index_col': 5,
#                                                 'left': 12.936617405582922,
#                                                 'right': 10.966965285554313,
#                                                 'samples': 174},
#                                       'samples': 479},
#                              'right': 9.035242290748899,
#                              'samples': 706},
#                     'right': {'col': 5,
#                               'cut_off': 0.422,
#                               'index_col': 5,
#                               'left': {'col': 7,
#                                        'cut_off': 0.29,
#                                        'index_col': 7,
#                                        'left': {'col': 2,
#                                                 'cut_off': 0.43,
#                                                 'index_col': 2,
#                                                 'left': {'col': 4,
#                                                          'cut_off': 0.926,
#                                                          'index_col': 4,
#                                                          'left': 12.261363636363637,
#                                                          'right': 17.0,
#                                                          'samples': 67},
#                                                 'right': 11.019047619047619,
#                                                 'samples': 172},
#                                        'right': {'col': 3,
#                                                  'cut_off': 0.18,
#                                                  'index_col': 3,
#                                                  'left': {'col': 6,
#                                                           'cut_off': 0.158,
#                                                           'index_col': 6,
#                                                           'left': {'col': 6,
#                                                                    'cut_off': 0.129,
#                                                                    'index_col': 6,
#                                                                    'left': 10.0,
#                                                                    'right': 17.083333333333332,
#                                                                    'samples': 15},
#                                                           'right': 12.94059405940594,
#                                                           'samples': 116},
#                                                  'right': 15.16,
#                                                  'samples': 141},
#                                        'samples': 313},
#                               'right': {'col': 7,
#                                         'cut_off': 0.3145,
#                                         'index_col': 7,
#                                         'left': 9.969465648854962,
#                                         'right': {'col': 5,
#                                                   'cut_off': 0.5815,
#                                                   'index_col': 5,
#                                                   'left': 11.024875621890548,
#                                                   'right': {'col': 4,
#                                                             'cut_off': 1.488,
#                                                             'index_col': 4,
#                                                             'left': 10.063063063063064,
#                                                             'right': 11.071428571428571,
#                                                             'samples': 139},
#                                                   'samples': 340},
#                                         'samples': 602},
#                               'samples': 915},
#                     'samples': 1621},
#            'right': {'col': 5,
#                      'cut_off': 0.566,
#                      'index_col': 5,
#                      'left': {'col': 7,
#                               'cut_off': 0.41,
#                               'index_col': 7,
#                               'left': 13.827586206896552,
#                               'right': 15.653846153846153,
#                               'samples': 107},
#                      'right': {'col': 7,
#                                'cut_off': 0.58,
#                                'index_col': 7,
#                                'left': {'col': 7,
#                                         'cut_off': 0.45,
#                                         'index_col': 7,
#                                         'left': 11.09016393442623,
#                                         'right': {'col': 5,
#                                                   'cut_off': 0.7075,
#                                                   'index_col': 5,
#                                                   'left': 13.705882352941176,
#                                                   'right': 11.734177215189874,
#                                                   'samples': 130},
#                                         'samples': 252},
#                                'right': {'col': 5,
#                                          'cut_off': 1.0515,
#                                          'index_col': 5,
#                                          'left': {'col': 6,
#                                                   'cut_off': 0.3985,
#                                                   'index_col': 6,
#                                                   'left': {'col': 3,
#                                                            'cut_off': 0.215,
#                                                            'index_col': 3,
#                                                            'left': 17.0,
#                                                            'right': 23.5,
#                                                            'samples': 12},
#                                                   'right': 15.733333333333333,
#                                                   'samples': 27},
#                                          'right': 11.428571428571429,
#                                          'samples': 34},
#                                'samples': 286},
#                      'samples': 393},
#            'samples': 2014},
#  'samples': 2798}

# %%
pred = model.prediction(X_test)
corr, MAE, RAE, RMSE, R2 = compute_error(y_test,pred)
print("\nCorrCoef: %.3f\nMAE: %.3f\nRMSE: %.3f\nR2: %.3f" %(corr, MAE,RMSE, R2))
# Out:
# CorrCoef: 0.711
# MAE: 1.564
# RMSE: 2.209
# R2: 0.499
